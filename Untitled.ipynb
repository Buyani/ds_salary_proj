# %%
import pandas as pd

# %%
df=pd.read_csv('glassdoor_jobs.csv')
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
#This line will open a new chrome window and start the scraping.
path="C:/Users/Admin/Desktop/2021/DataScience/EDA/ds_salary_proj/chromedriver";

df = get_jobs("data scientist", 15, False,path,15)
df
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-4-c07a086f8279> in <module>
#       2 path="C:/Users/Admin/Desktop/2021/DataScience/EDA/ds_salary_proj/chromedriver";
#       3
# ----> 4 df = get_jobs("data scientist", 15, False,path,15)
#       5 df
#
# <ipython-input-2-cf24fc160b04> in get_jobs(keyword, num_jobs, verbose, path, sleep_time)
#      10
#      11     #Change the path to where chromedriver is in your home folder.
# ---> 12     driver = webdriver.Chrome(executable_path=path, options=options)
#      13     driver.set_window_size(1120, 1000)
#      14
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
# ...
